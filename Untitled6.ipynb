# %%
import numpy.linalg as la
a = [[1, 2], [3, 4]]
la.inv(a)
# Out:
# array([[-2. ,  1. ],
#        [ 1.5, -0.5]])

# %%
import pandas as pd
import os
s = os.path.sep
df = pd.read_csv("c:" + s + 'Users' + s + 'train.csv' )

# %%
df
# Out:
#           ID  age         job   marital  education default  balance housing  \
# 0      26110   56      admin.   married    unknown      no     1933      no
# 1      40576   31     unknown   married  secondary      no        3      no
# 2      15320   27    services   married  secondary      no      891     yes
# 3      43962   57  management  divorced   tertiary      no     3287      no
# 4      29842   31  technician   married  secondary      no      119     yes
# ...      ...  ...         ...       ...        ...     ...      ...     ...
# 31642  36483   29  management    single   tertiary      no        0     yes
# 31643  40178   53  management  divorced   tertiary      no      380      no
# 31644  19710   32  management    single   tertiary      no      312      no
# 31645  38556   57  technician   married  secondary      no      225     yes
# 31646  14156   55  management  divorced  secondary      no      204     yes
#
# ...

# %%
df[df['poutcome'] == 'failure']
# Out:
#           ID  age          job  marital  education default  balance housing  \
# 28     30448   45   technician  married  secondary      no      858      no
# 36     45155   63      retired  married    primary      no     3738      no
# 41     41042   68      retired  married    primary      no     2301      no
# 44     42243   32   management  married   tertiary      no     1331      no
# 51     25061   45  blue-collar  married  secondary      no     1678     yes
# ...      ...  ...          ...      ...        ...     ...      ...     ...
# 31547  38410   54   unemployed  married  secondary      no      582     yes
# 31574  34551   57      retired  married  secondary      no        0     yes
# 31582  35298   47     services  married    unknown      no    12839     yes
# 31610  37564   47       admin.  married  secondary      no      120     yes
# 31645  38556   57   technician  married  secondary      no      225     yes
#
# ...

# %%
df[df['balance']>=0]
# Out:
#           ID  age         job   marital  education default  balance housing  \
# 0      26110   56      admin.   married    unknown      no     1933      no
# 1      40576   31     unknown   married  secondary      no        3      no
# 2      15320   27    services   married  secondary      no      891     yes
# 3      43962   57  management  divorced   tertiary      no     3287      no
# 4      29842   31  technician   married  secondary      no      119     yes
# ...      ...  ...         ...       ...        ...     ...      ...     ...
# 31642  36483   29  management    single   tertiary      no        0     yes
# 31643  40178   53  management  divorced   tertiary      no      380      no
# 31644  19710   32  management    single   tertiary      no      312      no
# 31645  38556   57  technician   married  secondary      no      225     yes
# 31646  14156   55  management  divorced  secondary      no      204     yes
#
# ...

# %%
df[df['education']== 'primary']
# Out:
#           ID  age          job   marital education default  balance housing  \
# 18     35310   44  blue-collar   married   primary      no     4031     yes
# 26      9934   60      retired   married   primary      no    17413      no
# 29     30566   53    housemaid    single   primary      no       80      no
# 32      1352   46  blue-collar   married   primary      no     -768     yes
# 36     45155   63      retired   married   primary      no     3738      no
# ...      ...  ...          ...       ...       ...     ...      ...     ...
# 31598  23756   49  blue-collar   married   primary      no      592      no
# 31622  44152   79      retired  divorced   primary      no     2787      no
# 31626   4031   57      retired   married   primary      no       70     yes
# 31628  36947   43   unemployed  divorced   primary      no      -70     yes
# 31636  20954   48    housemaid   married   primary      no      469      no
#
# ...

# %%
df1 = pd.read_csv("c:" + s + 'Users' + s + 'test.csv')

# %%
e = df[df['education'] == 'primary' ]
e
# Out:
#           ID  age          job   marital education default  balance housing  \
# 18     35310   44  blue-collar   married   primary      no     4031     yes
# 26      9934   60      retired   married   primary      no    17413      no
# 29     30566   53    housemaid    single   primary      no       80      no
# 32      1352   46  blue-collar   married   primary      no     -768     yes
# 36     45155   63      retired   married   primary      no     3738      no
# ...      ...  ...          ...       ...       ...     ...      ...     ...
# 31598  23756   49  blue-collar   married   primary      no      592      no
# 31622  44152   79      retired  divorced   primary      no     2787      no
# 31626   4031   57      retired   married   primary      no       70     yes
# 31628  36947   43   unemployed  divorced   primary      no      -70     yes
# 31636  20954   48    housemaid   married   primary      no      469      no
#
# ...

# %%
e[e['subscribed'] == 'yes']
# Out:
#           ID  age          job   marital education default  balance housing  \
# 18     35310   44  blue-collar   married   primary      no     4031     yes
# 131    15907   44   management   married   primary      no     4758     yes
# 138    28285   32  blue-collar   married   primary      no      634      no
# 150    31033   69      retired   married   primary      no     2346      no
# 170    43923   62      retired   married   primary      no     1742      no
# ...      ...  ...          ...       ...       ...     ...      ...     ...
# 31346  43584   63      retired   married   primary      no    12067      no
# 31470  44317   82    housemaid  divorced   primary      no     1381      no
# 31497  30482   40   unemployed   married   primary      no     1908     yes
# 31537  43636   72      retired   married   primary      no     2304      no
# 31622  44152   79      retired  divorced   primary      no     2787      no
#
# ...
