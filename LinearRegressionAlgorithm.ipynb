# %%
import pandas as pd
import os
s = os.path.sep
df = pd.read_csv('c:' + s + 'Users' + s + 'linear.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 4>()
#       2 import os
#       3 s = os.path.sep
# ----> 4 df = pd.read_csv('c:' + s + 'Users' + s + 'linear.csv')
#       5 df
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df = pd.get_dummies(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df = pd.get_dummies(df)
#
# NameError: name 'pd' is not defined

# %%
train = df[:7999]
test = df[8000:]

# %%
x_train = train.drop('Item_Outlet_Sales', axis = 1)
x_train.head()#only has independant variables
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0         9.30         0.016047  249.8092                       1999
# 1         5.92         0.019278   48.2692                       2009
# 2        17.50         0.016760  141.6180                       1999
# 3        19.20         0.000000  182.0950                       1998
# 4         8.93         0.000000   53.8614                       1987
#
#    Item_Identifier_DRA12  Item_Identifier_DRA24  Item_Identifier_DRA59  \
# 0                      0                      0                      0
# 1                      0                      0                      0
# 2                      0                      0                      0
# 3                      0                      0                      0
# 4                      0                      0                      0
#
#    Item_Identifier_DRB01  Item_Identifier_DRB13  Item_Identifier_DRB24  ...  \
# ...

# %%
y_train = train['Item_Outlet_Sales']
y_train.head()#shouls only have target variable
# Out:
# 0    3735.1380
# 1     443.4228
# 2    2097.2700
# 3     732.3800
# 4     994.7052
# Name: Item_Outlet_Sales, dtype: float64

# %%
x_test = test.drop('Item_Outlet_Sales', axis = 1)

# %%
y_test = test['Item_Outlet_Sales']
y_test
# Out:
# 8000    4454.2020
# 8001    4233.1564
# 8002    5033.4480
# 8003    1342.2528
# 8004    2446.1492
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 523, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
lg = LinearRegression()
lg
# Out:
# LinearRegression()

# %%
x_train = pd.get_dummies(x_train)
x_train
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0            9.30         0.016047  249.8092                       1999
# 1            5.92         0.019278   48.2692                       2009
# 2           17.50         0.016760  141.6180                       1999
# 3           19.20         0.000000  182.0950                       1998
# 4            8.93         0.000000   53.8614                       1987
# ...           ...              ...       ...                        ...
# 7994        10.50         0.027276  171.3106                       1997
# 7995        12.85         0.152748  252.0382                       2009
# 7996          NaN         0.060707  127.5020                       1985
# 7997         6.36         0.120788   45.7060                       2002
# 7998          NaN         0.076852  111.8570                       1985
#
#       Item_Identifier_DRA12  Item_Identifier_DRA24  Item_Identifier_DRA59  \
# ...

# %%
x_test = pd.get_dummies(x_test)
x_test
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 8000        7.020         0.081329  150.0734                       2002
# 8001        7.420         0.020388  247.1092                       2004
# 8002       17.250         0.113518  253.5724                       1997
# 8003       18.750         0.052917  190.6504                       2002
# 8004       20.250         0.018911  220.5772                       2007
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                       1987
# 8519        8.380         0.046982  108.1570                       2002
# 8520       10.600         0.035186   85.1224                       2004
# 8521        7.210         0.145221  103.1332                       2009
# 8522       14.800         0.044878   75.4670                       1997
#
#       Item_Identifier_DRA12  Item_Identifier_DRA24  Item_Identifier_DRA59  \
# ...

# %%
x_test.fillna(0,inplace = True )

# %%
x_train.fillna(0, inplace = True)

# %%
print(lg.fit(x_train, y_train))
# Out:
# LinearRegression()

# %%
pred = lg.predict(x_test)
#pred
p = lg.predict(x_train)

# %%
lg.score(x_train, y_train)#r-squared
# Out:
# 0.6497735631845378

# %%
lg.score(x_test, y_test)
# Out:
# 0.40227153690776773

# %%
import numpy as np
rmse_test = np.sqrt(np.mean(np.power(np.array(pred) - np.array(y_test), 2)))

# %%
rmse_test
# Out:
# 1255.3981735645664

# %%
rmse_train = np.sqrt(np.mean(np.power(np.array(lg.predict(x_train)) - np.array(y_train), 2)))

# %%
rmse_train
# Out:
# 1013.0040784390595
